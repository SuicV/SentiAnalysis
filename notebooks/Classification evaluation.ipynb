# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Evaluation de la classification

# %% [markdown]
# ### Importation des bibliothèques

# %%
import os
os.chdir("..")

# %%
import re
import pandas as pd
import spacy
nlp = spacy.load("en_core_web_sm")
from collections import Counter

# %%
tagged_hotels_corpus = open("data/tagged_hotels_corpus.txt", "r")

# %%
tagged_hotels_corpus.seek(3)
current_review_number = 1
review_text = []
temp_review_text = ""
for line in tagged_hotels_corpus.readlines():
    splited = line.split("###")
    sentence_text=splited[1]
    sentence_meta_data = splited[0]
    meta_data_items = sentence_meta_data.strip().split(" ")
    regex_groups = re.search(r'\[c([0-9]+)\]\[s([0-9]+)\]', meta_data_items[0]).groups()
    review_id = int(regex_groups[0])
    sentence_number = int(regex_groups[1])
    if current_review_number == review_id:
        temp_review_text += " " + sentence_text
    elif review_id == current_review_number+1:
        review_text.append(temp_review_text)
        temp_review_text = sentence_text
        current_review_number = review_id
# add add the last review
review_text.append(temp_review_text)

# %%
df = pd.DataFrame(review_text, columns=["review"])
df
# Out:
#                                                review
# 0     this is quite the most delightful hotel i ha...
# 1    the actual hotel accomodations were very luxu...
# 2    very good, but i am going back and won't stay...
# 3    we stayed here for one night, in december 201...
# 4    the family that runs this hostel are wonderfu...
# ..                                                ...
# 95   we arrived really late on friday evening and ...
# 96   bed and breakfast/ hostel style accommodation...
# 97   we stayed at cabanas del lago for one night f...
# 98   we found this place on the internet and staye...
# 99   this hotel is perfect!!!\n  we got two days o...
#
# [100 rows x 1 columns]

# %%
# Load opinion lexicon
neg_file = open("data/opinion-lexicon-English/negative_words.txt",encoding = "ISO-8859-1")
pos_file = open("data/opinion-lexicon-English/positive_words.txt",encoding = "ISO-8859-1")
neg = [line.strip() for line in neg_file.readlines()]
pos = [line.strip() for line in pos_file.readlines()]
opinion_words = neg + pos

# %%
def feature_sentiment(sentence):
    '''
    input: dictionary and sentence
    function: appends dictionary with new features if the feature did not exist previously,
              then updates sentiment to each of the new or existing features
    output: updated dictionary
    '''

    sent_dict = Counter()
    debug = 0
    for token in sentence:
    #    print(token.text,token.dep_, token.head, token.head.dep_)
        # check if the word is an opinion word, then assign sentiment
        if token.text in opinion_words:
            sentiment = 1 if token.text in pos else -1
            # if target is an adverb modifier (i.e. pretty, highly, etc.)
            # but happens to be an opinion word, ignore and pass
            if (token.dep_ == "advmod"):
                continue
            elif (token.dep_ == "amod"):
                for child in token.children:
                    # if there's a adj modifier (i.e. very, pretty, etc.) add more weight to sentiment
                    # This could be better updated for modifiers that either positively or negatively emphasize
                    if ((child.dep_ == "amod") or (child.dep_ == "advmod")):
                        sentiment *= 1.5
                    # check for negation words and flip the sign of sentiment
                    if child.dep_ == "neg":
                        sentiment *= -1
                sent_dict[token.head.lemma_.lower()] += sentiment
            # for opinion words that are adjectives, adverbs, verbs...
            else:
                for child in token.children:
                    # if there's a adj modifier (i.e. very, pretty, etc.) add more weight to sentiment
                    # This could be better updated for modifiers that either positively or negatively emphasize
                    if ((child.dep_ == "amod") or (child.dep_ == "advmod")):
                        sentiment *= 1.5
                    # check for negation words and flip the sign of sentiment
                    if child.dep_ == "neg":
                        sentiment *= -1
                for child in token.children:
                    # if verb, check if there's a direct object
                    if (token.pos_ == "VERB") & (child.dep_ == "dobj"):
                        sent_dict[child.lemma_.lower()] += sentiment
                        # check for conjugates (a AND b), then add both to dictionary
                        subchildren = []
                        conj = 0
                        for subchild in child.children:
                            if subchild.text == "and":
                                conj=1
                            if (conj == 1) and (subchild.text != "and"):
                                subchildren.append(subchild.lemma_.lower())
                                conj = 0
                        for subchild in subchildren:
                            sent_dict[subchild] += sentiment

                # check for negation
                for child in token.head.children:
                    if ((child.dep_ == "amod") or (child.dep_ == "advmod")):
                        sentiment *= 1.5
                    # check for negation words and flip the sign of sentiment
                    if (child.dep_ == "neg"):
                        sentiment *= -1
                
                # check for nouns
                for child in token.head.children:
                    noun = ""
                    if (child.pos_ == "NOUN") and (child.text not in sent_dict):
                        noun = child.lemma_.lower()
                        # Check for compound nouns
                        for subchild in child.children:
                            if subchild.dep_ == "compound":
                                noun = subchild.lemma_.lower() + " " + noun
                        sent_dict[noun] += sentiment
                    debug += 1
    return sent_dict

# %% [markdown]
# **Extraction des aspects et leurs sentiment avec les aspects réels et leurs sentiment**

# %%
tagged_hotels_corpus.seek(3)
current_review_number = 1
review_text = []
temp_review_text = ""

global_true_apsects = []
global_predicted_aspects = []

for line in tagged_hotels_corpus.readlines():
    splited = line.split("###")
    sentence_text=splited[1]
    sentence_meta_data = splited[0]
    aspects_metadata = splited[0].strip().split(" ", maxsplit=1)
    true_aspects = []
    if len(aspects_metadata) > 1:
        aspects_metadata = aspects_metadata[1].split(",")
        for aspect in aspects_metadata:
            if "[p]" in aspect or "[u]" in aspect or aspect == "" :
                continue
            else:
                true_aspects.append(aspect.strip())
    extracted_aspects_sentiment = dict(feature_sentiment(nlp(sentence_text)))
    print(true_aspects)
    predicted_aspects = []
    for __aspect in extracted_aspects_sentiment.keys():
        __sentiment = extracted_aspects_sentiment[__aspect]
        if __sentiment >= 0:
            predicted_aspects.append(f"{__aspect}[+]")
        else:
            predicted_aspects.append(f"{__aspect}[-]")
    global_true_apsects.append(true_aspects)
    global_predicted_aspects.append(predicted_aspects)
    print(true_aspects, predicted_aspects)
    print(sentence_text)
    print("=================")
# Out:
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  this is quite the most delightful hotel i have stayed in for a very long time.
#
# =================
# ['driveway[+]', 'entrance[+]', 'staff[+]']
# ['driveway[+]', 'entrance[+]', 'staff[+]'] ['driveway[+]']
#  charming and eventful driveway and entrance and very welcoming staff.
#
# =================
# ['owner[+]']
# ['owner[+]'] []
#  the owner is on hand much of the time to offer help and advice.
#
# =================
# ['room[+]', 'view lake[+]', 'view[+]']
# ['room[+]', 'view lake[+]', 'view[+]'] ['room[+]', 'view[+]']
#  the rooms are great and all have a decent view of the lake.
#
# =================
# ['room[+]', 'aspect[+]']
# ['room[+]', 'aspect[+]'] ['aspect[+]']
#  the public rooms have superb aspects of the surrounding country.
#
# =================
# ['garden[+]', 'pool[+]', 'lakeside[+]']
# ['garden[+]', 'pool[+]', 'lakeside[+]'] []
#  the gardens are beautifully kept and the pool and lakeside are so inviting.
#
# =================
# ['dinning[+]', 'wine choice[+]', 'wine[+]']
# ['dinning[+]', 'wine choice[+]', 'wine[+]'] ['dining[+]', 'choice[+]', 'wine[+]']
#  excellent dining and good choice of fine wines.
#
# =================
# ['place[-]', 'tennis court[-]', 'equipment[-]']
# ['place[-]', 'tennis court[-]', 'equipment[-]'] ['place[+]', 'tennis court[-]']
#  cannot fault the place although the tennis court is a little tired as is the equipment.
#
# =================
# []
# [] [' [+]']
#  just wonderful and would return there at the drop of a hat.
#
# =================
# ['dining [+]']
# ['dining [+]'] ['recommendation[+]', 'dining recommendation[+]']
#  some very good dining recommendations in the town of pucon.
#
# =================
# []
# [] []
#  they also arrange walks and hikes for you.
#
# =================
# []
# [] []
#  could not be faulted overall.
#
# =================
# []
# [] []
#  i don't write that very often!
#
# =================
# ['hotel[+]', 'accomodation[+]']
# ['hotel[+]', 'accomodation[+]'] ['hotel accomodation[+]']
#  the actual hotel accomodations were very luxurious and absolutely wonderful, but antumalal was too far away from the actual town of pucon.
#
# =================
# []
# [] []
#   we needed to take a taxi each time we wanted to go to town.
#
# =================
# ['service[+]', 'reception[-]', 'reception service[-]', 'stay[-]']
# ['service[+]', 'reception[-]', 'reception service[-]', 'stay[-]'] ['service[-]']
#  also, the service at the reception was horrible for all 4 days of our stay.
#
# =================
# ['receptionist[-]']
# ['receptionist[-]'] ['receptionist[-]']
#  the multiple receptionists were equally unhelpful when it came to questions about pucon activities or transportation to and from the airport.
#
# =================
# ['view[-]']
# ['view[-]'] [' [+]']
#  very good, but i am going back and won't stay there for the simple fact that they are blocks from the lake without a view that you could get in another hotel.
#
# =================
# ['breakfast[+]', 'juice[-]', 'toaster[-]', 'coffee[-]', 'room[-]', 'room night light[-]', 'room light[-]', 'night[-]']
# ['breakfast[+]', 'juice[-]', 'toaster[-]', 'coffee[-]', 'room[-]', 'room night light[-]', 'room light[-]', 'night[-]'] ['juice[-]', 'toaster[-]', 'coffee[+]']
#  besides that, breakfast was ok, bad juices, slow toaster, strong coffee, light coming in at night in my room.
#
# =================
# ['hotel[+]', 'room[+]', 'bed[+]', 'sheet[+]']
# ['hotel[+]', 'room[+]', 'bed[+]', 'sheet[+]'] ['hotel[+]', 'room[+]', 'bed[+]']
#  the hotel was extremely clean, the rooms where impeccable and the beds very comfortable and nice sheets and all that that is key.
#
# =================
# ['common area[+]', 'food[+]', 'hamburger[-]']
# ['common area[+]', 'food[+]', 'hamburger[-]'] [' [+]', 'area[+]', 'food[+]']
#  the common areas nice and clean, the food was pretty good, i did not like the hamburger do.
#
# =================
# []
# [] []
#  we stayed here for one night, in december 2011.
#
# =================
# []
# [] []
#  we weren't overly impressed by it at all.
#
# =================
# ['reception[-]', 'chef[-]', 'waitress[-]']
# ['reception[-]', 'chef[-]', 'waitress[-]'] []
#  firstly, we waited at the reception desk for 10 minutes to be checked in, with no-one in sight except a chef and waitress who carried on their coversation, ignoring us.
#
# =================
# []
# [] []
#  it would have been nice if they'd let someone know that there were guests waiting to be checked in at reception.
#
# =================
# []
# [] ['conversation[+]']
#  maybe their conversation was important, who knows.....?
#
# =================
# []
# [] []
#  they gave us a two single beds, instead of a double bed, but by that stage, we were too tired to care, and we thought that for one night it wasn't worth complaining about.
#
# =================
# ['room[-]', 'heating[-]']
# ['room[-]', 'heating[-]'] ['room[-]']
#  the room was a little cold, and the heating was off.
#
# =================
# ['hot water[-]']
# ['hot water[-]'] ['water[+]']
#  there was no hot water.
#
# =================
# []
# [] []
#  we were told that we needed to run it for at least three minutes for the heat to start coming through.
#
# =================
# []
# [] ['water[-]']
#  this proved to be more like 6 minutes (i felt horrible wasting water, but i was desparate for a shower!)
#
# =================
# []
# [] []
#  and even then it was barely warm.
#
# =================
# ['shower[-]']
# ['shower[-]'] []
#  the shower was mouldy, yuk!
#
# =================
# ['tv remote[-]', 'tv[-]']
# ['tv remote[-]', 'tv[-]'] ['tv remote[+]']
#  the tv remote didn't work.
#
# =================
# ['paint[-]', 'stay[-]']
# ['paint[-]', 'stay[-]'] ['stay[-]']
#  the paint in the hallway was peeling off due to the mould under it, over all i didn't enjoy my stay here, and was glad to be leaving it.
#
# =================
# ['bed[+]', 'breakfast[+]']
# ['bed[+]', 'breakfast[+]'] ['side[+]', 'bed[+]', 'breakfast[+]']
#  on the positive side, the beds were comfortable, and the breakfast was great!
#
# =================
# ['family[+]', 'hostel[+]']
# ['family[+]', 'hostel[+]'] ['people[+]']
#  the family that runs this hostel are wonderful, warm, helpful and delightful people.
#
# =================
# []
# [] []
#  they go out of their way to engage, accomodate and help you any way they can.
#
# =================
# ['room[+]']
# ['room[+]'] ['room[+]']
#  the room was comfortable enough although it had a hand-held shower wand.
#
# =================
# ['breakfast[+]']
# ['breakfast[+]'] ['breakfast[+]']
#  breakfast was adequate.
#
# =================
# ['propietor[+]']
# ['propietor[+]'] []
#  but it was the proprietor and his daughter that made the place wonderful.
#
# =================
# ['place[+]']
# ['place[+]'] ['place[+]']
#  lovely place, lot of activities and snow.
#
# =================
# ['staff[+]', 'room[+]']
# ['staff[+]', 'room[+]'] ['staff[+]', 'room[+]']
#  great staff that make you feel like in home with really nice and cute rooms.
#
# =================
# ['place[+]']
# ['place[+]'] ['place[+]']
#  a great place to make some ski, walking or only take a rest.
#
# =================
# []
# [] []
#  we stayed at the antumalal for four nights in march 2008.
#
# =================
# ['place[+]', 'setting[+]']
# ['place[+]', 'setting[+]'] ['place[+]', 'superb[+]']
#  this is an absolutely stunning place in a superb setting.
#
# =================
# ['garden[+]']
# ['garden[+]'] []
#  acres of beatifully maintained gardens (flowers!
#
# =================
# []
# [] []
#  waterfalls!)
#
# =================
# []
# [] ['beach[-]']
#  leading down to two small rocky beaches.
#
# =================
# ['room[+]']
# ['room[+]'] ['room[+]']
#  we stayed in the suite (room 9), next to the lobby but always quiet.
#
# =================
# ['bedroom[+]', 'bed[+]', 'fireplace[+]']
# ['bedroom[+]', 'bed[+]', 'fireplace[+]'] ['bed[+]']
#  the bedroom had a huge comfortable bed and a fireplace.
#
# =================
# ['sitting room[+]', 'sofa[+]', 'easy chair[+]', 'chair[+]', 'coffee table[+]', 'bookcase[+]', 'fireplace[+]']
# ['sitting room[+]', 'sofa[+]', 'easy chair[+]', 'chair[+]', 'coffee table[+]', 'bookcase[+]', 'fireplace[+]'] ['chair[+]']
#  the sitting room was huge, with two 2-person sofas, easy chair, coffee table, a second table with chairs, a built-in bookcase and a large fireplace.
#
# =================
# ['room[+]', 'window[+]', 'view[+]']
# ['room[+]', 'window[+]', 'view[+]'] []
#  both rooms have almost floor-to-ceiling windows with tremendous views.
#
# =================
# ['bathroom[+]']
# ['bathroom[+]'] ['bathroom[+]']
#  bathroom small but modern and tasteful.
#
# =================
# ['closet[+]']
# ['closet[+]'] []
#  there is a walk-in closet and lots of space for clothers and stuff.
#
# =================
# ['refrigerator[-]']
# ['refrigerator[-]'] ['refrigerator[-]']
#  the only thing lacking, surprisingly, was a minibar/refrigerator.
#
# =================
# ['front desk service[+]', 'service[+]']
# ['front desk service[+]', 'service[+]'] ['desk service[+]']
#  front desk service was excellent.
#
# =================
# ['terrace dinner[+]', 'dinner[+]']
# ['terrace dinner[+]', 'dinner[+]'] []
#  eating dinner on the terrace as the sun set is fabulous.
#
# =================
# ['lunch[+]']
# ['lunch[+]'] [' [+]']
#  great for lunch also.
#
# =================
# ['restaurant[+]', 'food[+]', 'service[-]']
# ['restaurant[+]', 'food[+]', 'service[-]'] ['restaurant food[+]', 'world class[+]', 'from[+]', 'service[-]']
#  the restaurant food was good although not world class, with service varying from fair to really slow.
#
# =================
# ['place[+]']
# ['place[+]'] ['drawback[-]', 'place[+]']
#  this is the only drawback to this fabulous place to spend some time.
#
# =================
# ['restaurant[+]']
# ['restaurant[+]'] ['restaurant[+]']
#  there are a number of good restaurants in pucon, only a couple miles away.
#
# =================
# ['hotel[+]', 'staff[+]']
# ['hotel[+]', 'staff[+]'] ['hotel puelche[+]', 'rate facility[+]']
#  hotel puelche is a first rate facility, exceeded only by its first rate staff.
#
# =================
# ['doorman[+]']
# ['doorman[+]'] ['bellhop[+]']
#  i failed to get his name, but the doorman/bellhop was particularly helpful during my stay.
#
# =================
# []
# [] []
#  it is true that the hotel isn't right in the city center.
#
# =================
# []
# [] ['walk[+]']
#  but puerto varas is small, and the short walk is pleasant.
#
# =================
# ['distance[+]']
# ['distance[+]'] ['distance[+]', 'issue[+]', 'health issue[-]']
#  the distance really is not an issue (except perhaps for those with specific health issues preventing them from short walks).
#
# =================
# ['hotel[+]', 'restaurant[+]']
# ['hotel[+]', 'restaurant[+]'] ['restaurant[+]']
#  it is worth noting that the hotel is steps away from the excellent restaurant imperial 605.
#
# =================
# ['hotel[+]', 'tv cable[+]', 'tv[+]', 'english[+]']
# ['hotel[+]', 'tv cable[+]', 'tv[+]', 'english[+]'] []
#  just a note if you don't speak spanish -- the hotel has cable tv with several channels in english.
#
# =================
# []
# [] []
#  of course, you probably won't be spending your time in puerto varas watching tv!
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]', 'it[+]']
#  this really is an exceptional small hotel, and i recommend it 100%.
#
# =================
# []
# [] []
#  we have just spent 5 days in the region, including two nights at the bellavista.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  the hotel is indeed as other have written: clean, facing the lake, very close to the casino.
#
# =================
# ['room[-]', 'room comfort[+]', 'heating[+]', 'fridge[+]', 'safe[+]', 'window[-]', 'hotel[-]', 'noise[-]']
# ['room[-]', 'room comfort[+]', 'heating[+]', 'fridge[+]', 'safe[+]', 'window[-]', 'hotel[-]', 'noise[-]'] ['room[+]', 'heating[+]', 'noise[-]']
#  the rooms are comfortable, have good heating, fridge and safe, but despite the double-glassed windows, noise comes through from the lakeside road that runs in front of the hotel.
#
# =================
# ['back room[-]']
# ['back room[-]'] []
#  there are no rooms facing the back.
#
# =================
# ['wi-fi[+]', 'wi-fi signal[+]', 'room[-]', 'lobby area[+]']
# ['wi-fi[+]', 'wi-fi signal[+]', 'room[-]', 'lobby area[+]'] ['wi[+]', 'fi[+]', 'signal[-]']
#  there is free wi-fi: but the signal is erratic in the room, but acceptable in the lobby area.
#
# =================
# []
# [] []
#  the hotel is a preferred spot for excursions of retired brazilians, traveling on buses.
#
# =================
# ['place[-]', 'stay[-]', 'region[+]']
# ['place[-]', 'stay[-]', 'region[+]'] ['region[+]']
#  but our main point is that puerto varas not the place to stay when visiting this beautiful region.
#
# =================
# []
# [] []
#  the city is charmless and noisy.
#
# =================
# []
# [] ['place[+]', 'beauty[+]', 'driver[-]']
#  there are much better places in ensenada, petrohue and frutillar, from which one can really connect with the gorgeous natural beauties of this region, without having to put up with cargo trucks and crazy cab drivers.
#
# =================
# []
# [] []
#  our advice is therefore that you rent a car and hit the roads around the lake, leaving puerto varas behind.
#
# =================
# []
# [] ['basis[+]', 'region[+]']
#  petrohue and frutillar are the perfect bases from which to explore and enjoy the region, so peaceful and beautiful, and less pricey too.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  palafitos is a great little boutique hotel in a renovated palafitos(stilt) house perched over the water incastro.
#
# =================
# ['environment[+]']
# ['environment[+]'] ['wood[+]', 'take[+]', 'hip[+]']
#  it's fine pale wood, light neutral colours and modern take on traditional rustic furniture and furnishings create a smart, hip but cosy environment.
#
# =================
# ['room[+]', 'room light[+]', 'balcony[+]', 'bathroom[+]', 'linen[+]', 'linen quality[+]']
# ['room[+]', 'room light[+]', 'balcony[+]', 'bathroom[+]', 'linen[+]', 'linen quality[+]'] ['room[+]', 'bathroom[+]', 'linen[+]']
#  rooms are quite compact but light and well appointed with balconies, smart bathrooms and good quality linen.
#
# =================
# ['dining area[+]', 'couch[+]', 'fire[+]', 'deck[+]', 'kitchen access[+]']
# ['dining area[+]', 'couch[+]', 'fire[+]', 'deck[+]', 'kitchen access[+]'] ['dining area[+]', 'deck[+]']
#  the lounge/ dining area is very warm and comfortable, with couches in front of an enormous fire, a large deck over the water and full access to the kitchen for a cup of tea or preparing a simple meal.
#
# =================
# ['breakfast[+]', 'bread[+]', 'cereal[+]']
# ['breakfast[+]', 'bread[+]', 'cereal[+]'] ['breakfast[+]', 'home[+]', 'cereal[+]', 'water[+]']
#  breakfast was great with delicious home made bread, good cereal (just add hot water for porridge!)
#
# =================
# []
# [] ['jam[-]']
#  and home made jam, with eggs if you want.
#
# =================
# ['staff[+]']
# ['staff[+]'] ['friendly[+]', 'staff[+]']
#  the staff were great, friendly and helpful, especially rosario.
#
# =================
# ['cafe[+]', 'restaurant[+]']
# ['cafe[+]', 'restaurant[+]'] ['cafe[+]']
#  it's about a 10 minute walk to the centre, but there are a cafe and restaurant a few doors away, both good.
#
# =================
# []
# [] ['hostal[+]']
#  while it's more expensive than a decent hostal we thought it was worth the extra.
#
# =================
# []
# [] ['addition[+]']
#  a great addition to the otherwise generally ordinary tourist accommodation in castro.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] []
#  this is my third visit to valdivia and the second to this hotel which is located near downtown but at the same time surrounded by nature, which is the truly essence of valdivia.
#
# =================
# ['room[+]']
# ['room[+]'] ['room[+]']
#  for my surprise the rooms were redecorated some months ago, like new.
#
# =================
# ['pool[+]']
# ['pool[+]'] ['that[+]']
#  something that we really enjoyed is that when it was raining we could use the outside heated swimming pool.
#
# =================
# []
# [] []
#  my children used the canoes and the bicycles in the sunny days.
#
# =================
# ['service[+]', 'people[+]']
# ['service[+]', 'people[+]'] ['service[+]']
#  the service is very good and the people was very kind..
#
# =================
# ['night activity[-]', 'night[-]']
# ['night activity[-]', 'night[-]'] []
#  they didn't have any activities during the night, so we had dinner at the hotel and then we went to downtown.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  i recommend this hotel as the best of the city.
#
# =================
# ['dog[-]', 'night[-]']
# ['dog[-]', 'night[-]'] ['sleep[-]']
#  the hotel is directly opposite a vet's surgery which also serves as a sanctuary for stray dogs, which bark all day and all night, so sleep is very hard to come by.
#
# =================
# ['hotel[-]', 'air-conditioning[-]']
# ['hotel[-]', 'air-conditioning[-]'] []
#  the hotel does not have air-conditioning, so it is usually necessary to leave the windows open.
#
# =================
# ['back room[+]']
# ['back room[+]'] ['room[-]', 'problem[-]']
#  the rooms at the back overlooking the garden suffer less from this problem.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  good and interesting hotel.
#
# =================
# ['decoration[+]', 'room[+]', 'localization[+]', 'price[+]']
# ['decoration[+]', 'room[+]', 'localization[+]', 'price[+]'] ['localization[+]', 'price[+]']
#  the decoration is very unique, the rooms are comfortable, good localization and we could negotiate a fair price.
#
# =================
# ['place[+]']
# ['place[+]'] []
#  stayed with my three children for three nights, as we toured the island...the place is located in the city of castro centrally located on the island.
#
# =================
# []
# [] []
#  nice, clean, simple but refined.
#
# =================
# ['kitchen[+]', 'living room[+]']
# ['kitchen[+]', 'living room[+]'] ['kitchen[+]']
#  great kitchen and living room to share with other guests.
#
# =================
# ['stay[+]']
# ['stay[+]'] []
#  highly recommed for a few nights stay in castro.
#
# =================
# ['room[-]', 'room size[-]']
# ['room[-]', 'room size[-]'] []
#  we were given a room the size of a cupboard for first 2 nights - smaller than some cabins we had had on a ship.
#
# =================
# ['room[+]', 'lake view[+]']
# ['room[+]', 'lake view[+]'] ['view[+]']
#  eventually on 3rd night we were changed to much larger room with lovely view of lake.
#
# =================
# ['hotel[-]', 'public room[-]', 'shop[-]', 'price[-]', 'breakfast[-]']
# ['hotel[-]', 'public room[-]', 'shop[-]', 'price[-]', 'breakfast[-]'] ['room[-]', 'shop[-]', 'hotel[+]']
#  large hotel which catered for large groups - impersonal public rooms, expensive shop and inferior breakfastmuch better hotels around
#
# =================
# []
# [] []
#  hotel frontera is actually two buildings across the street from each other.
#
# =================
# []
# [] []
#  i stayed in the original, older building.
#
# =================
# ['room[+]']
# ['room[+]'] []
#  the room was great- hardwood floors and very clean.
#
# =================
# ['tv[+]']
# ['tv[+]'] ['variety[+]']
#  tv with a variety of channels.
#
# =================
# ['wi-fi[+]', 'room[+]']
# ['wi-fi[+]', 'room[+]'] ['wi fi[+]']
#  wi-fi worked in my room although some of my colleagues who stayed on higher floors said it did not (i was on the second floor).
#
# =================
# ['computer[+]', 'internet[+]']
# ['computer[+]', 'internet[+]'] ['internet access[+]']
#  there are two computers off the lobby that had internet access and worked pretty well.
#
# =================
# ['breakfast[+]']
# ['breakfast[+]'] ['breakfast[+]']
#  great breakfast (huge spread!)
#
# =================
# []
# [] []
#  included every morning.
#
# =================
# []
# [] []
#  i don't recall the rate being more that $60 per night.
#
# =================
# []
# [] []
#  the hotel is walking distance (5 min) to the center of town, and near a small park.
#
# =================
# []
# [] []
#  not being in the center of town it is more quiet.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] []
#  temuco is not exactly a tourist city, but if you find yourself there, the hotel frontera will serve you well.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['house[+]', 'area[+]']
#  hotel weisserhaus is a lovely little guest house centrally located in puerto varas, in one of the most beautiful areas of chile.
#
# =================
# ['owner[+]']
# ['owner[+]'] ['daughter[-]']
#  the owner jorge and his daughter susan could not have been more helpful or accommodating.
#
# =================
# []
# [] ['peace[+]']
#  i had lived in the area around 40 years before as a peace corps volunteer and was very eager to see if everything was as wonderful as my memories.
#
# =================
# []
# [] []
#  i also was traveling with my daughter, her boyfriend, and her boyfriend's mother so i was eager to show her where i had lived when i was approximately her age.
#
# =================
# ['site[+]']
# ['site[+]'] ['site[+]']
#  susan arranged a car and driver for us for a long afternoon for only sixty dollars, and he took us to all the glorious sites that i remembered including lago llanquihue, lago todos los santos, the saltos de petrohue, laguna verde, and ensenada.
#
# =================
# ['lake[+]']
# ['lake[+]'] ['lake[+]']
#  the driver had a friend who arranged a boat trip for us at todos los santos, a stunningly beautiful lake the color of turquoise with the picture postcard volcan osorno towering over it.
#
# =================
# []
# [] ['town[+]', 'influence[+]']
#  jorge also showed us the next day where to catch the local bus for the short ride to frutillar, a beautiful town also on lago llanquihue which has a strong german influence from the immigrants.
#
# =================
# ['cake[+]']
# ['cake[+]'] ['piece[+]']
#  we had a delicious piece of tres leches cake, which is not to be missed.
#
# =================
# []
# [] []
#  we also had dinner in puerto varas at a restaurant called donde el gordito, which translates roughly as fat man's place, which had been visited by anthony bourdain.
#
# =================
# ['hotel[-]', 'room[+]', 'noise[-]']
# ['hotel[-]', 'room[+]', 'noise[-]'] ['room[-]', 'street noise[-]']
#  the hotel itself is small and the rooms were a bit loud because of street noise but they were immaculately clean.
#
# =================
# ['breakfast[+]', 'pasta[+]']
# ['breakfast[+]', 'pasta[+]'] ['breakfast[+]']
#  the breakfast was delicious with homemade pastas.
#
# =================
# ['coffee[-]']
# ['coffee[-]'] ['coffee[-]']
#  the coffee was as bad as i remembered, as well--instant!
#
# =================
# ['vacation[+]']
# ['vacation[+]'] ['vacation[+]']
#  it was an unforgettable vacation, and without jorge's help we would never have been able to see all that we did.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]', 'masterpiece[+]']
#  we loved this beautiful hotel--an architectural masterpiece built into the cliff above lake villarica in pucon, chile.
#
# =================
# ['view[+]']
# ['view[+]'] ['view[+]']
#  incredible views in all directions.
#
# =================
# ['fireplace[+]']
# ['fireplace[+]'] []
#  stone fireplaces everywhere.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['news[+]', 'hotel[+]']
#  the hotel is built in various levels on the cliff--but here is the good news for any travelers with disabilities: the driveway, lobby, dining room, patios, lounge spaces and most of the rooms are all on one level, making this spectacular hotel truly accessible.
#
# =================
# ['facility[+]', 'pool[+]', 'fireplace[+]', 'tennis court[+]', 'trail[+]', 'surrounding[+]']
# ['facility[+]', 'pool[+]', 'fireplace[+]', 'tennis court[+]', 'trail[+]', 'surrounding[+]'] []
#  facilities include an indoor/outdoor swimming pool with fireplace, a tennis court, and trails through the landscaped surroundings.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  this is the most incredible hotel i have ever seen.
#
# =================
# []
# [] []
#  i am writing from within the hotel, dec. 3, 2011.
#
# =================
# []
# [] ['writing[+]']
#  out of curiosity i read the reviews for this hotel, and laughed a bit at the creative writing.
#
# =================
# ['lobby[-]']
# ['lobby[-]'] ['rap[-]', 'lobby[-]', 'area[-]']
#  mostly what people have said is exactly right on, but i think the hotel has got an unfair bad rap for relatively minor things like a cold lobby or slightly dark areas.
#
# =================
# ['hotel[+]', 'room[+]', 'window[+]', 'location[+]', 'wifi[+]', 'service[+]', 'parking area[+]']
# ['hotel[+]', 'room[+]', 'window[+]', 'location[+]', 'wifi[+]', 'service[+]', 'parking area[+]'] ['hotel[+]', 'room[+]', 'location[+]', 'wifi[+]', 'service[+]', 'bonus[+]']
#  the bottom line is this hotel is very clean, the rooms are spacious and well lit with big windows, the location is literally perfect, there is free good wifi in the lobby areas, the service is friendly, and a big bonus is if you have a car they have an enclosed, gated, private, locked parking area, which is really great.
#
# =================
# ['hot water[+]', 'heater[+]', 'breakfast[-]']
# ['hot water[+]', 'heater[+]', 'breakfast[-]'] ['heater[+]', 'breakfast[+]']
#  one prior writer pointed out a few things which are also true, but not really that bad: water takes a long time to get hot--this is very true, but once it does get hot, it stays hot and even; cold--yes, it is a bit cold, but if you know how to work the heater, it quickly gets nice and warm in the room, and the heater is nearly silent; not a very good breakfast--i don't fully agree, although i have had better breakfasts.
#
# =================
# []
# [] []
#  maybe they have learned from the reviews.
#
# =================
# ['egg[+]', 'egg freshness[+]']
# ['egg[+]', 'egg freshness[+]'] ['egg[-]']
#  my eggs were freshly made just for me, and were nicely scrambled and served hot off the griddle, not overdone.
#
# =================
# ['bread[+]']
# ['bread[+]'] []
#  the breads were very plain as the prior writer said.
#
# =================
# ['croissant[+]']
# ['croissant[+]'] []
#  there were a couple of croissant like rolls which were fresh and slightly crispy.
#
# =================
# ['fruit[+]']
# ['fruit[+]'] ['fruit[+]']
#  the fruit was fine.
#
# =================
# ['yogurt[+]']
# ['yogurt[+]'] []
#  there was yogurt.
#
# =================
# ['coffee[-]']
# ['coffee[-]'] []
#  coffee was instant!
#
# =================
# ['juice[+]']
# ['juice[+]'] ['juice[+]']
#  juice was in fact fresh.
#
# =================
# ['cheese[+]']
# ['cheese[+]'] ['cheese[+]']
#  i thought the cheese was actually very good.
#
# =================
# ['breakfast[+]']
# ['breakfast[+]'] []
#  so, a kind of average breakfast.
#
# =================
# []
# [] ['thing[+]', 'door[+]', 'right[+]']
#  the main thing here is very clean; very spacious (i am in the first room to the right, down the hall through the door, then first right door).
#
# =================
# ['bathroom[+]']
# ['bathroom[+]'] ['bathroom[+]']
#  bathroom is large and everything works.
#
# =================
# ['towel[+]']
# ['towel[+]'] ['towel[+]']
#  towel is plush and feels new.
#
# =================
# []
# [] ['it[+]']
#  so, i like it, and was very, very surprised to see it so low on the list.
#
# =================
# []
# [] []
#  it will rise up over time.
#
# =================
# ['hotel[-]']
# ['hotel[-]'] ['hotel[+]', 'place[+]']
#  this hotel is fine for a day, maybe two, but there are better places in town.
#
# =================
# ['room[+]', 'view[+]', 'place[-]']
# ['room[+]', 'view[+]', 'place[-]'] ['room[+]', 'view[+]', 'place[-]']
#  the room was fine, kind of small, the view was nice, but the place is a little dark and dingy and in need of an upgrade.
#
# =================
# ['food[+]', 'service[+]']
# ['food[+]', 'service[+]'] ['nothing[+]', 'service[+]']
#  the food was ok, nothing great, and the service was fine.
#
# =================
# ['place[+]', 'place[-]']
# ['place[+]', 'place[-]'] ['charm[-]', 'warmth[+]']
#  it's a large place, seems to be geared to tour groups, but lacks charm or warmth.
#
# =================
# []
# [] []
#  i wouldn't go out of my way for it.
#
# =================
# []
# [] ['blooper[+]', ' [+]', 'hill[-]']
#  'very good' according to footprint....yet another blooper by themVery convenient to bus station, up steep hill.
#
# =================
# ['room[-]', 'wall[-]']
# ['room[-]', 'wall[-]'] []
#  small room with paper thin walls.
#
# =================
# ['bathroom[+]']
# ['bathroom[+]'] ['bathroom[-]']
#  bathroom not particularly clean but functional.
#
# =================
# ['breakfast[-]']
# ['breakfast[-]'] ['leftover[-]']
#  breakfast awful - leftovers from whoever had been there previously.
#
# =================
# ['crockery[-]']
# ['crockery[-]'] ['crockery[-]']
#  half eaten rolls, one tea bag each, and dirty crockery with animal hairs.
#
# =================
# []
# [] []
#  we checked out (checkout is 10am!)
#
# =================
# []
# [] []
#  and in to a hotel as vista al mar was full.
#
# =================
# ['room[-]', 'hot water[-]', 'staff[-]']
# ['room[-]', 'hot water[-]', 'staff[-]'] ['water[+]']
#  my room had no hot water and the staff was unconcerned and unhelpful.
#
# =================
# []
# [] []
#  they even refused to turn down the muzak at breakfast.
#
# =================
# []
# [] []
#  and i was the only person there!
#
# =================
# ['room[-]', 'internet[-]']
# ['room[-]', 'internet[-]'] []
#  my room had no internet, either.
#
# =================
# ['hotel[+]', 'location[+]']
# ['hotel[+]', 'location[+]'] ['location[+]']
#  this hotel has a great location right across from the lake and volcano.
#
# =================
# ['staff[+]']
# ['staff[+]'] ['staff[+]']
#  it is near all the shops in the center of town, and the staff was very friendly.
#
# =================
# ['room[+]']
# ['room[+]'] ['side[-]', 'room[+]']
#  the rooms were on the smallish side, but clean.
#
# =================
# ['breakfast[+]', 'staff[+]']
# ['breakfast[+]', 'staff[+]'] ['breakfast[+]']
#  the breakfasts were fairly good, and the staff was very quick to provide assistance.
#
# =================
# []
# [] []
#  i would definitely recommend.
#
# =================
# ['hotel[-]']
# ['hotel[-]'] ['hotel[+]']
#  the hotel is attractive, but showing its age a bit (1980s).
#
# =================
# ['carpet[-]', 'room ceiling[-]', 'room[-]']
# ['carpet[-]', 'room ceiling[-]', 'room[-]'] ['carpet[-]', 'curtain rail[-]']
#  the carpets are worn and there was a big hole in the ceiling of my room where a curtain rail had come away.
#
# =================
# ['pool[-]', 'sauna[-]']
# ['pool[-]', 'sauna[-]'] ['area[-]']
#  i also found the indoor pool area not terribly attractive and the sauna was not working.
#
# =================
# ['room[-]', 'balcony[+]', 'noise[-]']
# ['room[-]', 'balcony[+]', 'noise[-]'] []
#  my room had a balcony and the street outside was a bit noisy at times.
#
# =================
# ['lake view[-]']
# ['lake view[-]'] ['lake[+]']
#  contrary to what was stated in an earlier review these rooms do not directly overlook the lake although you can see it through the trees.
#
# =================
# ['garden[+]', 'breakfast[+]', 'fruit selection[+]', 'fruit[+]']
# ['garden[+]', 'breakfast[+]', 'fruit selection[+]', 'fruit[+]'] ['garden[+]', 'buffet breakfast[+]', 'selection[+]', 'fruit[+]']
#  there is an attractive inner courtyard/garden with recliners and the buffet breakfast is not at all bad, with a good selection of fresh fruit.
#
# =================
# []
# [] []
#  the adjoining cafe (paris?)
#
# =================
# ['coffee[+]']
# ['coffee[+]'] ['coffee[+]']
#  serves excellent coffee, something of a rarity in chile.
#
# =================
# ['wifi[+]']
# ['wifi[+]'] ['wifi[+]']
#  the wifi worked fine for me.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['option[+]']
#  all in all, not a bad but not a brilliant option.
#
# =================
# []
# [] []
#  we stopped at the hotel natura for the night in the middle of the two day "lake crossing".
#
# =================
# []
# [] []
#  those making the lake crossing can eat lunch there.
#
# =================
# ['hotel[-]', 'menu[-]']
# ['hotel[-]', 'menu[-]'] []
#  the hotel has the same menu for lunch and dinner.
#
# =================
# []
# [] []
#  my husband and i each ordered an appetizer for lunch.
#
# =================
# []
# [] []
#  spending the night at the hotel natura makes the lake crossing much more leisurely.
#
# =================
# []
# [] []
#  we had a leisurely lunch and then took an excursion.
#
# =================
# []
# [] []
#  after the excursion we took a short hike up to a waterfa;;/
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['reason[+]', 'time[+]']
#  unless you have a good reason to be centrally located in town, if you are in pucon for a relaxing, quiet, and refreshing time, stay at this hotel, period.
#
# =================
# []
# [] []
#  this hotel is only a 10 or so minute drive from the heart of town--even with bumper to bumper traffic after new year's fireworks, it only took us about 20 minutes to get back there.
#
# =================
# []
# [] []
#  but what a difference that short amount of distance and time makes.
#
# =================
# ['hotel[+]', 'experience[+]']
# ['hotel[+]', 'experience[+]'] ['hotel[+]']
#  i can honestly say that this was one of the best hotel experiences my husband and i have ever had.
#
# =================
# []
# [] ['luxury[+]', 'disappointment[-]', 'shabby[-]', 'sum[-]']
#  in fact, in recent years we have been gravitating toward vacation rentals, after too many experiences of supposedly "luxury" hotels ending in disappointment: perhaps it's a little shabby around the edges, perhaps the place is overrun by screaming kids, maybe you paid a ridiculous sum for a tiny room you can barely move around in.
#
# =================
# []
# [] []
#  or your room looked out into an alley.
#
# =================
# []
# [] []
#  etc.
#
# =================
# []
# [] []
#  not here.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  the hotel itself is exquisite, but in a very welcoming and comfortable way.
#
# =================
# []
# [] ['way[+]']
#  the best way i could describe it is to say that it has an overall "spa" feel, without the spa fettish.
#
# =================
# ['staff[+]']
# ['staff[+]'] ['staff[+]', 'doubt[-]']
#  the staff is so warm and inviting, yet totally professional--without a doubt, the best hotel staff i've run across since i can remember.
#
# =================
# ['stay[+]']
# ['stay[+]'] ['detail[+]', 'balance[-]']
#  they just couldn't do enough to make sure every detail of our stay was perfect, and yet left us be to the extent that we wanted it (a very difficult balance to strike).
#
# =================
# ['food[+]', 'ingredient[+]', 'food flavor[+]', 'food[+]', 'stay[+]']
# ['food[+]', 'ingredient[+]', 'food flavor[+]', 'food[+]', 'stay[+]'] ['food[+]', 'ingredient[+]']
#  the food was fantastic...a two-choice each course affair, made with fresh local ingredients, and some of the most flavorful we had during our stay at pucon.
#
# =================
# ['ground[+]', 'place[+]']
# ['ground[+]', 'place[+]'] ['ground[+]', 'hand[+]', 'blade[+]', 'aspect[+]']
#  the grounds are amazing--it looks like they hand-placed each blade of grass, and yet at the same time i didn't think twice about strolling across it from our room to the pool--everything about the place invites you to enjoy all aspects of it.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['surprise[+]', 'hotel[+]', 'wood[+]', 'hint[+]']
#  probably the nicest surprise among many while we were there was arriving back at the hotel on our first night there, shivering from a late-night volcanic spa excursion, to find that the not only was the hotel itself wonderfully warm (with the fantastic woods emitting wonderful hints of spice and perfume...one of the woods smells rather of cinnamon, perhaps oregan wood?
#
# =================
# ['room[+]']
# ['room[+]'] []
#  ), but the entire room had heated floor tiles.
#
# =================
# []
# [] ['mold[-]', 'dust[-]', 'dust allergy[-]']
#  i have terrible mold and dust allergies that are almost always activated to some degree, in most settings.
#
# =================
# []
# [] ['tingle[-]']
#  i did not catch the smallest tingle of an immune reaction during my entire stay in the hotel, or on its grounds.
#
# =================
# ['room[+]']
# ['room[+]'] ['material[+]']
#  the rooms are large and airy, the materials are clean and crisp without being spartan.
#
# =================
# []
# [] ['perfection[+]']
#  don't know what else to say, except that, for us, it was perfection.
#
# =================
# ['room[-]', 'terrace[+]', 'lounge chair[-]', 'chair[+]', 'lounge[+]']
# ['room[-]', 'terrace[+]', 'lounge chair[-]', 'chair[+]', 'lounge[+]'] ['thing[-]']
#  racking my brain, one strange thing was that the ground level rooms (one of which we requested, for instant access to the pools) have terraces but no lounge chairs.
#
# =================
# []
# [] ['problem[-]']
#  this was odd but certainly no problem, because upon request they brought a couple of chairs from the pool immediately.
#
# =================
# ['shower[+]']
# ['shower[+]'] ['robe[+]', 'shower[+]']
#  and due to the overall spa feel of the hotel, i would have really enjoyed a cushy robe to slip into after enjoying their fantastic showers.
#
# =================
# ['stay[+]']
# ['stay[+]'] ['thing[+]']
#  but other than that, i can't say enough good things about our stay.
#
# =================
# []
# [] []
#  one hundred dollars a night for this?
#
# =================
# []
# [] []
#  we would have paid twice that.
#
# =================
# []
# [] ['battery[-]']
#  and did i mention that we left our lights on in our 4 x 4, drained the battery on new year's, and were jump started at 10pm by friends of the front desk clerk?
#
# =================
# ['staff[+]']
# ['staff[+]'] ['you[+]']
#  thank you to all the staff, and particularly christine.
#
# =================
# []
# [] []
#  we will definitely make it back to pucon, and i can't imagine staying anywhere else.
#
# =================
# []
# [] ['people[+]']
#  we stayed here at the very end of the high season, so it was still quite warm, and a lot less people.
#
# =================
# ['hotel[+]', 'staff[+]']
# ['hotel[+]', 'staff[+]'] ['hotel[+]', 'staff[+]']
#  this hotel is beautiful, and the staff was very helpful and friendly.
#
# =================
# []
# [] []
#  it is located somewhat farther from the center of town, but we actually walked from the hotel to the center of town to dinner, and took a cab back after dinner.
#
# =================
# []
# [] ['cab ride[+]']
#  a cab ride was only about $5 us, so very inexpensive.
#
# =================
# ['pool[-]']
# ['pool[-]'] ['pool[+]', 'fear[-]']
#  the outdoor pool is gorgeous, however, there were lots of bees flying around, and made it impossible to eat or drink anything for fear of being stung.
#
# =================
# ['breakfast[-]', 'lake view[+]']
# ['breakfast[-]', 'lake view[+]'] ['breakfast[-]', 'view[+]']
#  breakfast was somewhat disappointing, but we were the only ones eating breakfast while looking out on some spectacular lake views.
#
# =================
# ['hot spring[-]']
# ['hot spring[-]'] ['spring[+]']
#  getting to any of the hot springs is difficult.
#
# =================
# []
# [] []
#  the hotel will arrange for a driver for you, but we had a rental car, and the main road to huife was closed, so we found ourselves off-roading in a tiny rental car.
#
# =================
# ['hotel[+]', 'room[+]', 'bed[+]']
# ['hotel[+]', 'room[+]', 'bed[+]'] ['room[+]']
#  we didn't have dinner at the hotel, but the rooms were nice and beds comfortable.
#
# =================
# ['fireplace[+]', 'stay[+]']
# ['fireplace[+]', 'stay[+]'] ['touch[+]', 'stay[+]', 'fireplace[+]']
#  the fireplace is a nice touch, and we really enjoyed our stay.
#
# =================
# ['place[+]']
# ['place[+]'] ['place[+]']
#  we even negotiated an off-season discount, so it was one of the cheaper places we stayed.
#
# =================
# []
# [] ['surprise[+]']
#  i was expecting to stay at the hotel peulla, then the only one that could be found in peulla, but for my great surprise my travel agent somehow managed to move me and all its clients to the brand new hotel natura.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  the hotel is excellent, comfortable and nicely decorated.
#
# =================
# ['dinning room[+]', 'landscape[+]']
# ['dinning room[+]', 'landscape[+]'] ['landscape[+]']
#  the dinning room has glasses all around, which allows you to be in touch in the fantastic landscape all the time.
#
# =================
# ['room[+]', 'bed[+]', 'shower[+]', 'balcony[+]']
# ['room[+]', 'bed[+]', 'shower[+]', 'balcony[+]'] ['floor[+]', 'shower[+]']
#  i got a corner room on the top floor, which had a king size bed, great shower, and a balcony where you could lay down and rest while looking at the mountains.
#
# =================
# []
# [] ['peace[+]']
#  also, since peulla is a 200 habitants village only used as a stop point for the andean lake crossing, silence and peace is all you'll get.
#
# =================
# []
# [] []
#  i'd definitely recommend.
#
# =================
# []
# [] []
#  a lot of things has been said about this hotel, most of it i agree with.
#
# =================
# ['lake view[+]', 'volcano view[+]', 'view[+]']
# ['lake view[+]', 'volcano view[+]', 'view[+]'] [' [+]']
#  most impressive of course, is the view over the lake and the snow-covered volcano.
#
# =================
# []
# [] [' [+]']
#  terrific!
#
# =================
# []
# [] []
#  anything else comes second.
#
# =================
# ['service[+]']
# ['service[+]'] ['service[+]']
#  the service is good.
#
# =================
# []
# [] ['drink[+]', 'sour[-]']
#  there is a welcome drink in the bar; what else is there to choose than pisco sour?
#
# =================
# []
# [] []
#  ok, from the bottle, not freshly shaken, but it tasted good.
#
# =================
# ['room[+]', 'bathroom[+]']
# ['room[+]', 'bathroom[+]'] ['decorate[+]', 'room[+]']
#  the room was spacious, newly decorated with nice bath room.
#
# =================
# []
# [] ['value[+]']
#  breakfast included for usd 105 in december, which i find good value for money.
#
# =================
# []
# [] []
#  the noice from the street has been mentioned.
#
# =================
# ['window[+]']
# ['window[+]'] []
#  i didnot notice, perhaps because of the (new) double glazed windows?
#
# =================
# ['location[+]', 'hotel[+]']
# ['location[+]', 'hotel[+]'] ['location[+]', 'what[+]']
#  the location of the hotel is good, close to the casino if that is what you like (good for all kind of drinks).
#
# =================
# []
# [] ['room[+]']
#  we had booked a superior double room with view of the lake.
#
# =================
# []
# [] []
#  when we arrived this was not available and we were offered a twin room overlooking the car park.
#
# =================
# ['room[-]', 'balcony[+]', 'view lake[+]', 'view[+]']
# ['room[-]', 'balcony[+]', 'view lake[+]', 'view[+]'] ['problem[-]']
#  we refused to accept it, which caused some problems, but finally were given a room with a small balcony and a bit of a view of the lake.
#
# =================
# ['room[-]']
# ['room[-]'] []
#  the room was very small even though it was claimed to be superior.
#
# =================
# ['breakfast[+]']
# ['breakfast[+]'] ['breakfast[+]']
#  breakfast was good with a range of choice beyond a simple argentinean breakfast.
#
# =================
# []
# [] []
#  trip advisor review team: this review is for hotel colonos del sur mirador, and not gran hotel colones del sur.
#
# =================
# ['view[+]']
# ['view[+]'] ['view[+]']
#  some of your reviews for the former really relate to the latter, which does have good views
#
# =================
# ['location[+]']
# ['location[+]'] ['location[+]']
#  excellent location right in front of Villarica lake.
#
# =================
# ['view lake[+]', 'view[+]']
# ['view lake[+]', 'view[+]'] ['view[+]']
#  wonderful lake view.
#
# =================
# ['room[+]']
# ['room[+]'] ['room[+]']
#  very large room, clean, nicely maintained.
#
# =================
# ['breakfast[-]']
# ['breakfast[-]'] ['breakfast[+]']
#  wonderful breakfast.
#
# =================
# ['pool[-]']
# ['pool[-]'] ['refresh[+]']
#  indoor pool was a little bit old, needs a refresh soon!
#
# =================
# ['attendant[-]']
# ['attendant[-]'] []
#  attendants could also be more attentious.
#
# =================
# ['service[+]']
# ['service[+]'] ['service[+]']
#  offers good services (tour office inside, gym, etc) and is incredibly close to the main streets in city center.
#
# =================
# []
# [] []
#  would definitely come back.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] []
#  the hotel is really good located, just steps from pubs, restaurants and the casino.
#
# =================
# []
# [] ['overview[+]']
#  it has a really nice overview of the lake.
#
# =================
# ['dinner[+]', 'spa[+]', 'hotel[+]']
# ['dinner[+]', 'spa[+]', 'hotel[+]'] ['staurant[+]', 'spa[+]']
#  the staurant is good for dinner if you want to stay at the hotel and you have a very good spa.
#
# =================
# ['room[-]', 'noise[-]', 'price[+]']
# ['room[-]', 'noise[-]', 'price[+]'] ['room[-]', 'value[+]']
#  if you can resist the noisy rooms (you can hear everything from upstairs or neighboors) its a good value for the price
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['option[+]']
#  this hotel was a very nice option.
#
# =================
# ['personnell[+]', 'stay[+]']
# ['personnell[+]', 'stay[+]'] ['personnel[+]', 'allot[+]']
#  personnel was very friendly and helped us allot during our stay.
#
# =================
# ['view[+]', 'lake view[+]', 'volcano view[+]']
# ['view[+]', 'lake view[+]', 'volcano view[+]'] ['view[+]']
#  it has very nice views of the lakes and volcanoes.
#
# =================
# ['food[-]', 'food options[-]', 'reception[-]']
# ['food[-]', 'food options[-]', 'reception[-]'] ['food[-]', 'reception procesa[-]']
#  needs to importe: food options in general and the reception procesa (to slow and organized)
#
# =================
# ['hotel[+]', 'view[+]', 'room[+]']
# ['hotel[+]', 'view[+]', 'room[+]'] ['hotel[+]', 'view[+]', 'bit[-]']
#  good hotel, clean & functional with good views and Ok rooms, but a bit too big and impersonal for my taste.
#
# =================
# ['hotel[+]', 'view[+]', 'volcano view[+]']
# ['hotel[+]', 'view[+]', 'volcano view[+]'] ['hotel[+]', 'view[+]']
#  great hotel right on the lake, when the clouds clear the views of volcano osorno are spectacular.
#
# =================
# []
# [] ['shirt[-]']
#  right in the centre of Puerto Varas, so a short walk to shops, restaurants and the casino if you want to lose the shirt off your back.
#
# =================
# ['hotel[+]', 'location[+]']
# ['hotel[+]', 'location[+]'] ['location[+]']
#  this contemporary hotel is in a good location to walk downtown.
#
# =================
# ['staff[+]']
# ['staff[+]'] ['staff[+]']
#  staff was friendly and helpful.
#
# =================
# ['restaurant[+]', 'food[+]']
# ['restaurant[+]', 'food[+]'] ['food[+]']
#  good food in the restaurant.
#
# =================
# ['room[-]', 'night[-]']
# ['room[-]', 'night[-]'] ['night[-]']
#  a little noisy one night as our room was right above a party but all quieted down after 11PM.
#
# =================
# ['wifi[+]', 'lobby[+]']
# ['wifi[+]', 'lobby[+]'] []
#  wifi in the lobby.
#
# =================
# ['experience[+]']
# ['experience[+]'] ['experience[+]']
#  overall a pleasant experience.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  nice very avarage hotel .
#
# =================
# ['room[+]']
# ['room[+]'] ['room[+]']
#  rooms were clean and simple.
#
# =================
# ['breakfast[+]']
# ['breakfast[+]'] []
#  breakfast was ok.
#
# =================
# ['hotel[-]', 'view[-]', 'room[-]']
# ['hotel[-]', 'view[-]', 'room[-]'] ['view[-]']
#  the hotel is not located on the lake, the view from the rooms is quite limited.
#
# =================
# ['staff[-]', 'english[-]']
# ['staff[-]', 'english[-]'] []
#  the staffs' english is very limited.
#
# =================
# ['hotel[+]', 'price[-]']
# ['hotel[+]', 'price[-]'] []
#  the hotel is a bit over priced.
#
# =================
# []
# [] []
#  we stayed there 3 nights.
#
# =================
# []
# [] ['mall[+]']
#  it has a good mall 2 minutes walking.
#
# =================
# ['room[+]']
# ['room[+]'] ['clean[+]', 'room[+]']
#  the room was good, clean.
#
# =================
# ['staff[+]', 'breakfast[-]']
# ['staff[+]', 'breakfast[-]'] ['staff[+]', 'breakfast[-]']
#  the staff very friendly, the breakfast not so good as a brazilian breakfast.
#
# =================
# ['internet[+]']
# ['internet[+]'] [' [+]']
#  internet free for 20 min.
#
# =================
# []
# [] []
#  - 3 pcs.
#
# =================
# []
# [] []
#  two single beds, room rate 77 usd.
#
# =================
# ['hotel[+]', 'room[+]']
# ['hotel[+]', 'room[+]'] ['hotel[+]', 'room[+]']
#  nice hotel, beautiful and clean rooms, on the lake.
#
# =================
# ['room[-]']
# ['room[-]'] ['problem[-]', 'casino[-]', 'room[-]']
#  the only problem is the casino across the street, they play music outside until 4 am and if your room is on this side, too bad for you, bring your ear plugs...
#
# =================
# []
# [] ['regret[+]']
#  our only regret was not staying longer.
#
# =================
# ['bedroom[+]', 'view[+]', 'lake view[+]']
# ['bedroom[+]', 'view[+]', 'lake view[+]'] ['view[+]']
#  the bedroom was wide and had a terrific view to the lake.
#
# =================
# ['bed[+]', 'microwave[+]', 'bathtub[+]']
# ['bed[+]', 'microwave[+]', 'bathtub[+]'] ['bed[+]']
#  equipped with microwave, mini-bar, nice bed, bathtub.
#
# =================
# ['breakfast[+]']
# ['breakfast[+]'] ['breakfast[+]']
# ...
#
# =================
# []
# [] ['village[+]', 'setting[+]']
#  it's a quiet little village in a beautiful andes mountain setting.
#
# =================
# ['spot[+]']
# ['spot[+]'] ['spot[+]']
#  by the time the one-day crossers were leaving at 4:15, i thought we had seen everything and should be going with them.24 hours later, i was really glad we had stayed in this beautiful, tranquil spot.
#
# =================
# []
# [] ['view[+]']
#  we hiked the trail up to the cascada de la novia waterfall, then continued on up the trail to the canopy platform and got another good view.
#
# =================
# []
# [] []
#  a little grocery store in the village sells bottled water and snacks.
#
# =================
# []
# [] ['place[+]', 'itinerary[-]']
#  peulla is a wonderful place to rest up in the middle of a hectic touring itinerary.
#
# =================
# []
# [] []
#  but you want to know about the hotel.
#
# =================
# []
# [] ['natura[+]']
#  there are two in peulla, the 100 year old hotel peulla, and the bright, new hotel natura.
#
# =================
# []
# [] []
#  they are owned by the same people.
#
# =================
# []
# [] []
#  it's up to you, whether you want old and atmospheric or new and modern.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['natura[+]']
#  we sure liked the hotel natura.
#
# =================
# ['room[+]', 'room light[+]', 'decor[+]']
# ['room[+]', 'room light[+]', 'decor[+]'] []
#  the rooms are light and modern, with rustic decor, basic but comfortable.
#
# =================
# ['room[+]', 'patio[+]', 'chair[+]']
# ['room[+]', 'patio[+]', 'chair[+]'] ['scenery[+]']
#  our room was on the ground floor, so had a small patio with chairs for reading and enjoying the scenery.
#
# =================
# ['public space[+]', 'view[+]', 'mountain view[+]']
# ['public space[+]', 'view[+]', 'mountain view[+]'] ['space[+]', 'meadow[+]']
#  the public spaces are beautiful and large, with sweeping meadow and mountain views.
#
# =================
# []
# [] ['nook[+]', 'floor[+]', 'gem[+]']
#  tip: for a quiet reading nook without the background music, take the elevator to the sitting area off the 5th floor atrium, a hidden gem.
#
# =================
# ['dining room[+]', 'food[+]', 'dessert[-]']
# ['dining room[+]', 'food[+]', 'dessert[-]'] ['dining room[+]', 'dessert[+]']
#  the dining room is lovely and features above average food and presentations, though the desserts were over sweet and under flavored.
#
# =================
# ['hotel[+]', 'food[+]']
# ['hotel[+]', 'food[+]'] []
#  we also ate at the hotel peulla, where the setting is totally different and the food more traditional and perhaps a bit better.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] []
#  you should try both.
#
# =================
# ['staff[+]']
# ['staff[+]'] ['staff[+]']
#  the staff were friendly and generally helpful.
#
# =================
# ['wi-fi[+]', 'internet[+]', 'lobby[+]', 'lounge[+]']
# ['wi-fi[+]', 'internet[+]', 'lobby[+]', 'lounge[+]'] ['fi[+]', 'terminal[+]']
#  there is free wi-fi in the lobby and lounge, and a free internet terminal.
#
# =================
# []
# [] []
#  but all was not well.
#
# =================
# ['laundry[-]', 'laundry price[+]', 'hotel[-]']
# ['laundry[-]', 'laundry price[+]', 'hotel[-]'] ['price[+]', 'it[-]', 'desk[-]']
#  after telling us there was no rush to get our laundry in (and the prices were great), the front desk then refused it, saying the hotel's machines were too busy.
#
# =================
# ['dinner[-]']
# ['dinner[-]'] ['napkin[+]']
#  just as well, perhaps, judging by my clean but damp cloth napkin at dinner.
#
# =================
# ['lunch[-]', 'setting[-]']
# ['lunch[-]', 'setting[-]'] []
#  at lunch we were seated at a table with two used settings which were never removed, and a used dish of butter which was never replaced.
#
# =================
# ['breakfast[-]', 'coffee[-]']
# ['breakfast[-]', 'coffee[-]'] []
#  at breakfast, an upturned coffee cup was replaced on the old saucer and spoon.
#
# =================
# ['shower[-]']
# ['shower[-]'] ['shower water[-]']
#  our afternoon shower water was cold.
#
# =================
# ['towel[-]', 'towel quality[-]']
# ['towel[-]', 'towel quality[-]'] ['quality[-]']
#  we started with two bath and one hand towel between us, of poor quality.
#
# =================
# ['room[-]']
# ['room[-]'] []
#  we paid 30% extra to stay until our 4 pm boat departure, but the room was not made up.
#
# =================
# ['safe[-]']
# ['safe[-]'] []
#  it had possibly the world's smallest safe.
#
# =================
# ['building[+]', 'staff[+]']
# ['building[+]', 'staff[+]'] ['building[+]', 'staff[+]']
#  none of this soured us on the beautiful building and friendly staff.
#
# =================
# ['place[+]', 'building[+]']
# ['place[+]', 'building[+]'] ['place[+]']
#  it was not possible to stay irritated at the small things in such a beautiful place, especially in a new building which kept the scenery in front of us wherever we went.
#
# =================
# []
# [] []
#  we arrived in the morning pouring rain after an overnight bus trip from valparaiso.
#
# =================
# ['hotel[-]']
# ['hotel[-]'] []
#  it was a long walk through puddles to find the hotel, tip - continue on the bus to pucon and get a taxi to the hotel.
#
# =================
# ['dining room[+]', 'lake view[+]', 'view[+]']
# ['dining room[+]', 'lake view[+]', 'view[+]'] ['room[+]']
#  on arrival we were immediately offered breakfast in the beautiful dining room overlooking the lake whilst our room was prepared.
#
# =================
# ['fire[+]', 'room[+]', 'view[+]']
# ['fire[+]', 'room[+]', 'view[+]'] ['view[+]']
#  we were thrilled to find the fire going when we got to our room which also had great views.
#
# =================
# ['stay[+]', 'place[+]']
# ['stay[+]', 'place[+]'] ['place[+]']
#  this is a great place to stay.
#
# =================
# ['staff[+]', 'atmosphere[+]', 'welcome[+]', 'facility[+]']
# ['staff[+]', 'atmosphere[+]', 'welcome[+]', 'facility[+]'] ['staff[+]', 'atmosphere[+]']
#  the staff are marvellous, the welcome warm, great atmosphere and the facilities are superb.
#
# =================
# []
# [] []
#  we didn't want to leave.
#
# =================
# ['location[+]', 'staff[+]', 'room[+]']
# ['location[+]', 'staff[+]', 'room[+]'] ['location[+]', 'staff[+]']
#  the location is very convenient i this city (puerto varas), The staff is very helpful and warm, i very like the big rooms.
#
# =================
# []
# [] []
#  would come back!
#
# =================
# []
# [] []
#  us$92/night3 nightsin center of town.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  clean, quiet, older hotel, more like a b&b.
#
# =================
# ['tv[+]']
# ['tv[+]'] []
#  tv.
#
# =================
# ['breakfast[+]', 'bread[+]', 'cheese[+]', 'sandwich[+]', 'jam[+]', 'cake[+]']
# ['breakfast[+]', 'bread[+]', 'cheese[+]', 'sandwich[+]', 'jam[+]', 'cake[+]'] []
#  breakfast included bread, cheese, sandwich meat, jams, kuchen or some other cake.
#
# =================
# []
# [] ['restaurant[+]']
#  shops, tour agencies, many good and varied restaurants, casino, walk along the lake all close by..
#
# =================
# []
# [] ['communication[+]', 'recommendation[+]']
#  first of all, the communication before our arrival was excellent , christian answered all our questions and gave us recommendations about activities and stuff to do in town (pucon).
#
# =================
# ['location[+]']
# ['location[+]'] ['location[+]']
#  the location is easy to get to but keep your eyes open is way up the mountain.
#
# =================
# []
# [] []
#  is right after the liucuria river bridge.
#
# =================
# ['property[+]', 'owner[+]']
# ['property[+]', 'owner[+]'] ['property[+]', 'owner[+]']
#  their property is beautiful , well maintained and the owners are friendly and eager to help you.
#
# =================
# ['animal[+]']
# ['animal[+]'] []
#  they have many animals ,like sheep, rabbits, many different birds ectâ€¦ you are in nature.
#
# =================
# ['view[+]', 'cabin[+]', 'fire[+]']
# ['view[+]', 'cabin[+]', 'fire[+]'] ['view[+]', 'clean[+]', 'cabin[+]']
#  and the view was unreal... cabins are great, very clean and with a fire place.
#
# =================
# ['place[+]', 'noise[+]']
# ['place[+]', 'noise[+]'] ['car[+]', 'noise[-]']
#  place is quiet, no cars, or noise from other people.
#
# =================
# []
# [] []
#  is in the countryâ€¦ really, but just 15 min.
#
# =================
# []
# [] []
#  drive to pucon.
#
# =================
# ['hot water[+]', 'breakfast[+]', 'poeople[+]']
# ['hot water[+]', 'breakfast[+]', 'poeople[+]'] ['water[+]', 'people[+]']
#  hot water , breakfast and loving people.
#
# =================
# ['recommendation[+]']
# ['recommendation[+]'] ['recommendation[+]']
#  the recommendations for canopy, rafting and horseback riding where excellent , safe and affordable.
#
# =================
# ['owner[+]', 'owner family[+]', 'gift[+]']
# ['owner[+]', 'owner family[+]', 'gift[+]'] ['owner[+]']
#  we where there during christmas and on the 25th the owners and their family dress up like santa and went to all the cabins, bringing breakfast and a gift for us.
#
# =================
# ['place[+]', 'stay[+]']
# ['place[+]', 'stay[+]'] ['place[+]']
#  (accompany by a heard of sheep) i highly recommend this place for your stay in pucon, chile
#
# =================
# []
# [] ['hotel solace[+]']
#  i spent 3 nights at hotel solace over the course of an 8 day trip.
#
# =================
# ['room[+]', 'staff[+]']
# ['room[+]', 'staff[+]'] ['room[+]', 'staff[+]']
#  the hotel is only a block from town (close to restaurants, shopping, atms) with simple, comfortable rooms and friendly staff.
#
# =================
# ['seating area[+]', 'space[+]']
# ['seating area[+]', 'space[+]'] ['space[+]']
#  my favorite space was the seating area in front of the fireplace -- a great space to relax with a glass of wine.
#
# =================
# ['breakfast[+]', 'breakfast selection[+]']
# ['breakfast[+]', 'breakfast selection[+]'] ['selection[+]']
#  the breakfast buffet was simple but with a good selection.
#
# =================
# ['room[+]']
# ['room[+]'] ['room[+]']
#  the rooms can be warm as the windows only open slightly.
#
# =================
# ['night[+]', 'dog[-]']
# ['night[+]', 'dog[-]'] []
#  i did not experience a night of barking dogs as some other reviewers have but the hotel is located next to a veterinary clinic and there are many dogs in town.
#
# =================
# ['staff[+]']
# ['staff[+]'] ['staff[+]']
#  the staff was helpful but if you don't know any spanish it may be a bit difficult to communicate.
#
# =================
# ['hotel[+]', 'attention[+]', 'staff[+]', 'food[+]', 'room[+]', 'location[+]']
# ['hotel[+]', 'attention[+]', 'staff[+]', 'food[+]', 'room[+]', 'location[+]'] ['hotel[+]', 'staff[+]', 'room[+]', 'location[+]']
#  excellent hotel, attention to the details, great staff and food, amazing room, location is just excellent and quiet.
#
# =================
# ['service[+]', 'waiter[+]', 'staff[+]', 'reception[+]']
# ['service[+]', 'waiter[+]', 'staff[+]', 'reception[+]'] ['service[+]', 'waiter[+]', 'staff[+]']
#  the service was excellent: the waiters in the breakfast room were very friendly and the staff at the reception was always willing to help.
#
# =================
# ['breakfast[+]']
# ['breakfast[+]'] ['breakfast[+]', 'it[+]']
#  the breakfast is delicious, we highly recommend it!
#
# =================
# []
# [] []
#  we arrived really late on friday evening and were shown our rooms.
#
# =================
# ['spot[+]']
# ['spot[+]'] ['spot[+]']
#  what a perfect spot.
#
# =================
# ['room[+]', 'table[+]', 'chair[+]']
# ['room[+]', 'table[+]', 'chair[+]'] []
#  we stayed in the lodge and the room was earth tone red with our own little table and chairs.
#
# =================
# ['bed[+]']
# ['bed[+]'] ['bedding[+]']
#  the bedding was beautiful.
#
# =================
# ['ceiling[+]', 'fireplace[+]']
# ['ceiling[+]', 'fireplace[+]'] []
#  the ceiling had exposed rafters and we had a fireplace!
#
# =================
# ['host[+]', 'gift[+]']
# ['host[+]', 'gift[+]'] ['bottle[+]']
#  it was a birthday weekend and the hosts kindly left a box of local chocolates as a gift with the complementary bottle of wine.
#
# =================
# ['ground[+]']
# ['ground[+]'] []
#  the grounds were all green and nothing was out of place.
#
# =================
# []
# [] []
#  we loved staying here even though it was just outside of town.
#
# =================
# []
# [] []
#  it was on a hillside that overlooked the lake.
#
# =================
# []
# [] ['space[+]']
#  it was at this place we decided our current living style needed to change into this warm eclectic inviting space.
#
# =================
# []
# [] []
#  hope we will be back again, left my heart in pucon!
#
# =================
# ['house[+]']
# ['house[+]'] ['house[+]']
#  bed and breakfast/ hostel style accommodation lovely old house restored nicely.
#
# =================
# ['place[+]']
# ['place[+]'] ['place[-]']
#  this place is a bit hard to find but once there it is very central.
#
# =================
# ['room[+]', 'bed[+]']
# ['room[+]', 'bed[+]'] ['room[+]']
#  comfortable rooms and beds were great.
#
# =================
# ['staff[+]']
# ['staff[+]'] ['staff[+]', 'suggestion[+]']
#  the staff were very helpful with good suggestions.
#
# =================
# []
# [] ['town[+]']
#  much better to stay here than puerto montt as there is lots to do in the area and the town is lovely.
#
# =================
# []
# [] ['bay[+]']
#  it has a beautiful bay.
#
# =================
# ['breakfast[+]']
# ['breakfast[+]'] []
#  breakfasts are the usual basic but you can add extras like muesli, eggs and real coffee for a little extra.
#
# =================
# ['bike[+]', 'hostel[+]']
# ['bike[+]', 'hostel[+]'] []
#  you can hire bikes from the hostel.
#
# =================
# []
# [] []
#  we stayed at cabanas del lago for one night following a lake crossing from bariloche.
#
# =================
# []
# [] []
#  we arrived at 8p.m.
#
# =================
# []
# [] []
#  and had to leave at 8 a.m. the following day, but i do have a few impressions.
#
# =================
# ['view[+]', 'room[+]', 'amenity[+]', 'staff[+]', 'food[+]']
# ['view[+]', 'room[+]', 'amenity[+]', 'staff[+]', 'food[+]'] ['what[+]', 'room[+]', 'staff[+]']
#  what we liked: the view, the attractive room with all amenites, the pleasant staff, the food.
#
# =================
# ['service[-]', 'restaurant[-]']
# ['service[-]', 'restaurant[-]'] ['what[-]']
#  what we did not like: service in the restaurant.
#
# =================
# []
# [] []
#  a tour group was being served, and no one else was eating.
#
# =================
# []
# [] []
#  a local family-from grandparents on down-finally got up and left after receiving nothing but their drinks after more than an hour.
#
# =================
# []
# [] ['stare[-]']
#  we, for some reason, were served before several other customers who had been there longer, and their hungry stares made us very uncomfortable.
#
# =================
# ['food[+]', 'price[+]']
# ['food[+]', 'price[+]'] ['food[+]', 'price[+]']
#  the food was excellent, however, and the price very reasonable.
#
# =================
# ['hot water[-]']
# ['hot water[-]'] ['problem[+]', 'lack[+]', 'water[+]', 'bath[-]']
#  another problem: lack of hot water; we are not fond of lukewarm baths.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  the hotel is beautiful, as is the whole area.
#
# =================
# []
# [] ['spite[-]', 'problem[-]']
#  in spite of the problems, i would go back and spend more time there.
#
# =================
# []
# [] []
#  we found this place on the internet and stayed there three nights.
#
# =================
# []
# [] []
#  we walked right in (april) and got $65/night for a double with queen bad.
#
# =================
# ['outside[-]', 'hotel[+]']
# ['outside[-]', 'hotel[+]'] []
#  the outside of the hotel looks a little run down but it's much nicer inside.
#
# =================
# ['room[+]']
# ['room[+]'] ['room[+]']
#  clean rooms.
#
# =================
# ['view[+]', 'lake view[+]']
# ['view[+]', 'lake view[+]'] ['view[+]']
#  we had a great view of the lake.
#
# =================
# []
# [] []
#  it's not super close to downtown but the buses and taxis/colectivos are very cheap.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  this hotel is perfect!!!
#
# =================
# []
# [] []
#  we got two days of non-stop rain, so it was very helpfull to have direct entrance to the shopping mall!!!
#
# =================
# ['room[+]', 'view[+]']
# ['room[+]', 'view[+]'] []
#  the room we stayed in had a wonderfull view.
#
# =================
# ['hotel[+]']
# ['hotel[+]'] ['hotel[+]']
#  this hotel is modern, clean and new!
# =================

# %%
from spacy import displacy

# %%
displacy.render(nlp("!, but whats really horrible is the way the staff treat tourists, rud, bad face and very impolite!!"))
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6df16b7b3e90459ebf38b5c19ed4dadf-0" class="displacy" width="3550" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">really</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">horrible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">way</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">staff</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">treat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">tourists,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">rud,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">bad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">face</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">impolite!!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-1" stroke-width="2px" d="M420,352.0 C420,2.0 1275.0,2.0 1275.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-2" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-3" stroke-width="2px" d="M770,352.0 C770,89.5 1270.0,89.5 1270.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">csubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-4" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6df16b7b3e90459ebf38b5c19ed4dadf-0-4" class="displacy-label" startOffset="50%"

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
multilabel_binaraizer = MultiLabelBinarizer()
multilabel_binaraizer = multilabel_binaraizer.fit(global_true_apsects)

# %%
b_global_true_apsects = multilabel_binaraizer.transform(global_true_apsects)

# %%
b_global_predicted_aspects = multilabel_binaraizer.transform(global_predicted_aspects)
# Out:
# e:\pychcarmprojects\s4\servqc_ml\venv\lib\site-packages\sklearn\preprocessing\_label.py:875: UserWarning: unknown class(es) [' [+]', ' [-]', '4x4[+]', 'access[+]', 'addition[+]', 'allot[+]', 'amazement[+]', 'area[+]', 'area[-]', 'bait[-]', 'balance[-]', 'basis[+]', 'bath[-]', 'battery[-]', 'bay[+]', 'beach[-]', 'beauty[+]', 'bedding[+]', 'bellhop[+]', 'bet[+]', 'bike loan[-]', 'bit[+]', 'bit[-]', 'blade[+]', 'blooper[+]', 'bonus[+]', 'bottle[+]', 'break[-]', 'breakfast buffet[+]', 'buffet breakfast[+]', 'cab ride[+]', 'car[+]', 'casino[-]', 'change[+]', 'charm[+]', 'charm[-]', 'cheescake[+]', 'choice[+]', 'cigarette smoke[-]', 'city[-]', 'clean[+]', 'coffee smell[-]', 'colonos[+]', 'comment[-]', 'communication[+]', 'complex[-]', 'construction work[+]', 'conversation[+]', 'convient[+]', 'curtain rail[-]', 'daughter[-]', 'day[+]', 'day[-]', 'decision[-]', 'decorate[+]', 'design[+]', 'desk service[+]', 'desk[-]', 'dessert[+]', 'detail[+]', 'dining recommendation[+]', 'dining[+]', 'disappointment[-]', 'dish[+]', 'door[+]', 'doubt[-]', 'downside[-]', 'drawback[-]', 'drink[+]', 'driver[-]', 'dump[-]', 'dust allergy[-]', 'dust[-]', 'ease[+]', 